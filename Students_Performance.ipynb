# %% [markdown]
# <a href="https://colab.research.google.com/github/anu3200/Assignment/blob/main/Students_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import statistics as stat

# %%
df = pd.read_csv('/content/StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %% [markdown]
# 1. **Find** **out how many males and females participated in the test**

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# **2.What do you think about the students parental level of education**

# %%
df['parental level of education']
# Out:
# 0        some high school
# 1             high school
# 2        some high school
# 3            some college
# 4            some college
#               ...
# 995          some college
# 996          some college
# 997          some college
# 998    associate's degree
# 999     bachelor's degree
# Name: parental level of education, Length: 1000, dtype: object

# %%
exams = df[['math score', 'reading score', 'writing score']]

for i in exams:
    exam_pivot = pd.pivot_table(df,columns = 'parental level of education', values = i, aggfunc = 'mean')
    display(exam_pivot)
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# math score                            67.977477          69.288136
#
# parental level of education  high school  master's degree  some college  \
# math score                     61.821429        70.254237     67.128319
#
# parental level of education  some high school
# math score                          63.134078
# parental level of education  associate's degree  bachelor's degree  \
# reading score                         71.018018               73.0
#
# parental level of education  high school  master's degree  some college  \
# reading score                  64.602041        75.949153     69.566372
#
# parental level of education  some high school
# reading score                       66.759777
# parental level of education  associate's degree  bachelor's degree  \
# writing score                         70.031532          73.381356
#
# parental level of education  high school  master's degree  some college  \
# writing score                  62.403061        75.677966     69.035398
#
# parental level of education  some high school
# writing score                       64.888268

# %% [markdown]
# In this Pivot table, it can be noted that if the parent has a higher level of education, the students score increases.

# %% [markdown]
# 3.who scoores the most on average for math,reading and writing based on
# Gender , test preparation course.

# %%
df['average score']=(df['math score']+df['reading score']+df['writing score'])/3
df['average score']
# Out:
# 0        9.000000
# 1       18.333333
# 2       26.000000
# 3       27.000000
# 4       31.333333
#           ...
# 995     89.000000
# 996     94.000000
# 997     98.666667
# 998     97.666667
# 999    100.000000
# Name: average score, Length: 1000, dtype: float64

# %%
sns.scatterplot(x=df['average score'],y=df['math score'],hue=df['gender'])

# %%
sns.scatterplot(x=df['average score'],y=df['reading score'],hue=df['gender']

# %%
sns.scatterplot(x=df['average score'],y=df['writing score'],hue=df['gender'])

# %%
sns.scatterplot(x=df['average score'],y=df['math score'],hue=df['test preparation course'])

# %%
sns.scatterplot(x=df['average score'],y=df['reading score'],hue=df['test preparation course'])

# %%
sns.scatterplot(x=df['average score'],y=df['writing score'],hue=df['test preparation course'])

# %% [markdown]
# 4. **What do you think about the scoring variation for math, reading and writing        based on gender , test preparation** **course**

# %%
 df.boxplot(['math score','reading score', 'writing score'],['gender'])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9475488c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f947531e890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f94752d3910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f947528d850>]],
#       dtype=object)

# %%
df.boxplot(['math score','reading score', 'writing score'],['test preparation course'])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f94750bd210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94750cd0d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9475082150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f947503d190>]],
#       dtype=object)

# %%
 df.boxplot(['average score'],['gender'])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# **5**. **The management needs your help to give bonus points to the top 25% of             students based on their math score,so how will you help the management           to achieve this**

# %%
stat.stdev(df['math score'])
# Out:
# 15.569566802272002

# %%
stat.variance(df['math score'])
# Out:
# 242.4114104104104
